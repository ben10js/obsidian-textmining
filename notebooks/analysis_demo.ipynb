# %%
import sys
import os
sys.path.append(os.path.abspath('../'))  # obsidian_txtmining이 있는 폴더의 상위경로 추가

# %%
from obsidian_txtmining.saver import load_vectorizer, load_matrix, load_features, load_token
from obsidian_txtmining.tokenizer import Tokenizer
from obsidian_txtmining.config import CUSTOM_STOPWORDS, DESIRED_POS_TAGS, DOC_SEPARATOR

# 1. 기준 코퍼스 정보 불러오기
doc_vectors = load_matrix('C:/Users/User/Documents/personal_recommender/data/document_vectors.joblib')
vectorizer = load_vectorizer('C:/Users/User/Documents/personal_recommender/data/vectorizer.joblib')
feature_names = load_features('C:/Users/User/Documents/personal_recommender/data/feature_names.joblib')

# %%
file_path = 'C:/Users/User/Documents/personal_recommender/data/merged_obsidian_notes.txt'  
with open(file_path, 'r', encoding='utf-8') as f:
    text = f.read()

# 여러 md 글 파일이 하나 있으면 문서 분리(예: 헤더 기준 ### 등)
doc_list = text.split('\n=====\n')

# %% [markdown]
# # 사용자 쿼리에 대해 토큰화 진행

# %% [markdown]
# # doc list를 돌면서 문서정보를 기억하면서, 각 문서에 대해 토큰화 및 벡터화 진행

# %%
from obsidian_txtmining.tokenizer import Tokenizer

tokenizer = Tokenizer(stopwords=CUSTOM_STOPWORDS, pos_tags=DESIRED_POS_TAGS)
tokenized_query = tokenizer.each_tokenize(doc_list)
tokenized_query[3]
# Out:
# '동선 박사 영상 보고 춤추다 스포츠 운동 시토신 나오다 행복감 느끼다 트라우마 나오다 연결 비슷하다 고통 이기 트라우마 극복 위해 필요하다 가지 한가지 페스티벌 시간 예술인 음악 기반 모두 형식 시간 동기화 공연 자의 음악 기준 재료 모두 동기화 자아 동일성 기여 자아 실체 그리다 따라서 동기화 자아 확장 타인 군중 공연 감상 거대하다 벤다이어그램 우리 자아 포함 이기 때문 사랑 경험 치다 특성 나라 자아 우리 크다 범위 확장 경험 동시 외감 형식 공간 무대 연출 통해 정도 동기화 물론 벡터 엄밀하다 같다 공간 모두 않다 관련 공연 자의 음악 과련된 연출 모두 동기화 페스티벌 동기화 기반 함께 움직임 더하다 함께 뛰다 함성 지르다 모습 시토신 분비 스포츠 유사하다 페스티벌 느끼다 쾌감 시토신 통한 대감 출처'

# %%
print(tokenized_query)
# Out:
# ['지메일 기록 본문 한글파일 확인', '이상형 열정 영혼 가지다 사람 이상형 열정 가지다 사람 현재 모습 볼품 없다 상관없다 계속 늘다 중요하다 파도 타다 타다 크게 중요하다 않다 파도 본인 어떻다 없다 상황 영역 그녀 발전 열정 의지 보다 노력 보다 자기 상황 좋다 가져가다 솜씨 좋다 여성 솜씨 힘드다 여성 생리 때문 기적 신체 안정 깨지다 정신과 신체 연결 돼다 생각 따라서 여성 정신 남성 비다 불안정하다 따라서 솜씨 가다 필요조건 안정 충족 솜씨 가다 무언가 쌓다 나가다 힘드다 그래서 여성 대해 서다 실력 능력 측면 보지 않다 지다 열정 의지 건강하다 방향 인지 보다 가치관 일치 건강하다 방향 판단 너무 나르시시즘 이렇다 논리 남성은 신체 정신 안정 크다 여성 남성 능력 조건 같다 솜씨 나타내다 지표 보다 남성은 의지 열정 충분하다 않다 남성은 여성 들다 솜씨 높다 안정 요구 반면 여성 상대 강점 하나 존재 바로 불안 정성 나오다 즐거움 취향 전문성 장인정신 재미 모두 균형 거리 멀다 개념 들이다 취향 전문성 분야 깊다 파고 들어가다 그러하다 재미 극단 반전 변화 나오다 쇼펜하우어 철학 고통 없어지다 상태 인간 지루함 느끼다 재미 찾기 위해 고통 스스로 만들다 존재 재미 고통 없어지다 상태 고통 가깝다 상태 재미 변화 로부터 나오다 변화 안정 거리 멀다 개념 따라서 여성 상대 불안 정성은 남성 비다 재미 주다 즐거움 만들다 좋다 장점 불안 정성 극단 세로토닌 가깝다 즐거움 재미 감정 다른 극단 슬픔 슬픔 또한 의미 사용 슬픔 위로 중요하다 감정 여성 공감 능력 뛰어나다 이유 즐거움 슬픔 같다 극단 정선 쉬다 가까워지다 상대 불안 정성 때문 생각 안정 상태 자다 띄다 않다 때문 분명하다 안정 상태 존재 자다 띄다 않다 때문 불안 정적 상태 즐거움 슬픔 전이 사람 공감 표현 안정 상태 분명 존재 전이 위기 차분하다 맞서다 리더 모습 보고 안정감 얻다 바로 이렇다 전이 불안 정성은 상대 자다 띄다 그래서 관심 받다 매력 보이다 여성 남성 비다 불안정하다 때문 이렇다 불안 정성 장점 또한 모두 가져가다 여성 존재 자체 재미있다 즐거움 주다 매력 사랑받다 마치 아이 그렇다 그래서 여성 아이 사랑 보호 남성 자연스럽다', '윤수 단계 생기 대한 의지 열정 단계 자기 절제 끈기 노력 부차 단계 효율 환경 조성 어리다 성숙하다 동생 대한 관심 건강하다 결과 이끌다 동생 바랬 동생 발전 방향 자라다 바랬다 당시 동생 단계 해당 자기 절제 끈기 노력 중요하다 생각 단계 강조 공부 독려 과정 단계 자체 가치 강조 내적 동기 자극 아니다 걱정 불안 외적 동기 주입 결과 둘째 동생 단계 능력 치다 점점 약해지다 결국 생기 없어지다 무기력증 동생 찾아오다 대한 의지 열정 약해지다 없어지다 결국 자살 생각 관심 가지다 자연스럽다 증도 자연스럽다 당시 자신 성숙하다 균형 잡히다 시각 가지 문제 동생 대한 관심 지금 그대로 당시 성숙하다 때문 방식 동생 자극 주다 의도 좋다 결과 나쁘다 관심 애증 같다 관심 가져오다 결과 좋다 애정 보이 관심 가져오다 결과 나쁘다 증오 보이다 그래서 애정 증오 차이 아니다 그래서 애증 단어 아니다 이렇다 성찰 나서다 둘째 동생 대한 처방 단계 대한 모든 연상 않다 유도 가족 단계 대한 않다 되어다 오히려 단계 강조 결국 둘째 동생 단계 능력 치르다 회복하다 자연스레 스스로 단계 능력 유지 성취 가져가다 문제 둘째 동생 대한 조치 막내 동생 동일하다 적용 해당 처방 조치 막내 동생 둘째 동생 상황 다르다 단계 단계 균형 발달 상황 같다 당시 가족 분위기 둘째 단계 회복 시키다 집중 분위기 때문 둘째 회복 과정 자연스레 막내 단계 강조 단계 강조 않다 결과 지금 막내 단계 역량 부족하다 상황 되어다 막내 생기다 자기 절제 능력 부족하다 스스로 대한 진지하다 기분 들어서다 열정 솟을 열정 나오다 생각 실천 옮기다 오래 가져가다 행동 부족하다 열정 오래 가지 않다 금방 크다 타오르다 어느새다 불씨 남다 식다 이렇다 열정 성질 생각 열정 그저 계기 열정 오래 가져가다 불가능하다 본능 퇴행 열정 식히다 열기 그대로 가져가다 단계 끈기 노력 열정 불꽃 본능 퇴행 식히다 반대 자기 절제 본능 퇴행 열기 없애다 만들다 자기 절제 열기 가져가다 본능 퇴행 활동 범위 제한 끈기 노력 열기 목표 지점 가져가다 중요하다 끈기 노력 열기 유지 행위 같다 생기 대한 의지 열기 같다 열정 시간 짧다 불꽃 우연 계기 화재 마음 붙다 열정 생겨나다 화재 따르다 불꽃 크기 온도 다르다 영원하다 불꽃 없다 아무리 크다 뜨겁다 불꽃 금방 불씨 돌아가다 본능 퇴행 그렇게 만들다 한번 불꽃 불씨 존재 이상 대기 이전 뜨겁다 열기 존재 본능 퇴행 열기 본능 가깝다 밀다 발전 피어 열기 뺏다 열기 행적 발전 모두 피어 본능 퇴행 열기 본능 가깝다 가져가다 자기 절제 본능 퇴행 대해 방향 열기 가져가다 인간 행적 발전 모두 필요하다 영역 모두 대해 열기 균형 잡다 중요하다 본능 분명 우리 구성 절제 욕구 분명하다 우리 구성 본능 퇴행 자기 절제 서로 끊임없다 투쟁 우리 정신 유지 본능 퇴행 인간 동물 정신과 가깝다 본능 퇴행 없다 기계 무생물 본능 퇴행 자기 절제 법적 권리 의무 관계 비슷하다 인간 존엄성 신체 인간 권리 본능 제한 존엄 신체 인권 본능 떼다 없다 인간 존재 우리 세계 신체 물질 표현 인간 정신 존재 인간 정신 신체 성과 반대 절제 욕구 가지 인간 하여금 자기 절제 의무 가능하다 권리 의무 동전 양면 붙다 서로 균형 맞추다 법적 아름답다 인간 신체 성과 정신 성도 균형 맞다 아름답다', '동선 박사 영상 보고 춤추다 스포츠 운동 시토신 나오다 행복감 느끼다 트라우마 나오다 연결 비슷하다 고통 이기 트라우마 극복 위해 필요하다 가지 한가지 페스티벌 시간 예술인 음악 기반 모두 형식 시간 동기화 공연 자의 음악 기준 재료 모두 동기화 자아 동일성 기여 자아 실체 그리다 따라서 동기화 자아 확장 타인 군중 공연 감상 거대하다 벤다이어그램 우리 자아 포함 이기 때문 사랑 경험 치다 특성 나라 자아 우리 크다 범위 확장 경험 동시 외감 형식 공간 무대 연출 통해 정도 동기화 물론 벡터 엄밀하다 같다 공간 모두 않다 관련 공연 자의 음악 과련된 연출 모두 동기화 페스티벌 동기화 기반 함께 움직임 더하다 함께 뛰다 함성 지르다 모습 시토신 분비 스포츠 유사하다 페스티벌 느끼다 쾌감 시토신 통한 대감 출처', '음악 미술 숙련 과정 모방 필요하다 음악 미술 예술 경지 가다 자기 만들다 이러하다 창작 음악 작곡 미술 드러나다 감상 서양 미술사 읽다 렘브란트 그림 해설 보고 느끼다 그림 처음 보다 그저 자연스럽다 조화 오다 보이다 해설 오리엔트 의상 광택 질감 붕뜨 않다 두운 배경 조화 시키다 렘브란트 대단하다 드러나다 써다 해설 처음 감상 느끼다 어렵다 왜냐하면 조화롭다 독특하다 않다 때문 집중 사로자다 쉽다 보이다 사람 그만큼 숙련 돼다 생각나다 음악 마찬가지 절대 음악 영역 가보다 바흐 클래식 단지 조화롭다 들다 졸리다 뿐이다 중학생 시리다 악단 음악회 들다 가다 졸리다 지금 크게 그러하다 조화 대단하다 감동 느껴지다 않다 성적 생각 감각 느껴지다 않다 회화 제대로 감상 이유 절대 음악 감상 이유 이제야 알다 감상 의미 모르다 작품 제대로 감상 바로 작가 고뇌 상상 전율 느껴지다 겠다 표면 감각 감상 다르다 감상 의미 동시 의미 감각 이뤄지다 감상 겠다 감상 시간 필요하다 누구 누구 주다 바로 창작 어떠하다 평가 주다 겠다 따라서 감상 창작 자의 창작 과정 작품 등장 배경 맥락 생각 감상 필요조건 창작 대한 공감 직접 예술 행위 해보다 경험 부족하다 단순하다 조화 자연스럽다 뻔하다 않다 방법 연출 위해 창작 과정 창작 자의 고뇌 노력 재능 기지 느끼다 느끼다 알다 창작 공감 창작 공감 고뇌 노력 공감 공감 창작 과정 대한 공감 시대 배경 맥락 대한 공감 나뉘다 전자 직접 경험 통해 후자 간접 경험 통해 공감 깊이 깊다 직접 경험 예술 행위 직접 해보다 모방 창작 간접 경험 배경 공부 예술사 가능하다 예술사 공부 그러하다 공감 성적 만들다 예술 행위 대한 직접 경험 그러하다 공감 감성 느껴지다 만들다 칸트 따르다 이성은 판단력 지니다 감상 지성 감성 영역  ...

# %%
vectorizer_all_docs = load_vectorizer('C:/Users/User/Documents/personal_recommender/data/vectorizer.joblib')
tfidf_vectorizer_all_docs = vectorizer_all_docs

each_document_matrix = tfidf_vectorizer_all_docs.transform(tokenized_query)

# Get the feature names (words) for all documents
feature_names_all_docs = tfidf_vectorizer_all_docs.get_feature_names()

# 4. Print the shape of the resulting document_tfidf_matrix and the number of features.
print(f"TF-IDF Matrix shape for all documents: {document_tfidf_matrix.shape}")
print(f"Number of features (unique words) for all documents: {len(feature_names_all_docs)}")
# Out:
# TF-IDF Matrix shape for all documents: (201, 7040)
# Number of features (unique words) for all documents: 7040

# %% [markdown]
# # 이제 토큰화했던 유저쿼리를, doclistquery 벡터공간 기준으로 코사인유사도를 계산하여, 고빈도토큰이 최근접한 문서를 추천

# %%
user_query = " 예술 옥시토신 음악 시간 내감 영감"

# %%
from obsidian_txtmining.recommender import recommend_document

# 이제 토큰화했던 유저쿼리를, doclistquery 벡터공간 기준으로 코사인유사도를 계산하여, 고빈도토큰이 최근접한 문서를 추천
recommended_docs = recommend_document(user_query, vectorizer_all_docs, each_document_matrix, doc_list, top_n=2, tokenizer=tokenizer)

# %%
print(recommended_docs)
# Out:
# [{'document_index': np.int64(42), 'similarity_score': np.float64(0.3787140314509959), 'original_document_snippet': '영상은 사진의 나열이다. 사진에 대해서는 공간예술적인 재료가 포함돼있으며, 그 사진을 시간선에 대해 나열한다는 점에서 시간예술적 측면도 가지고 있다. 영화예술의 형식은 시간에 근거하며, 질료는 공간에 근거한다. (? 좀 더 고민이 필요한 문장이다) 게임은 차원이 다르다. 체험요소가 들어가있기 때문이다. 그래서 나에겐 아직 감상하고 설명하기가 어렵다. 나는 ...'}, {'document_index': np.int64(27), 'similarity_score': np.float64(0.2386980188146657), 'original_document_snippet': '음악을 시각화하는 면도 내 관심사이자 사이드비전 중 하나이고, 그것을 카이스트 및 표준화평가과와 함께 이과적으로도 접근하는 등, 분야를 넘나들어 과업을 완성하려는 인문학적 소양이 작가의 행보와 인터뷰, 글에서 돋보인다. 동시에 경제적으로 볼 때도, 케이옥션에 막 출품하지 않은 작가인것으로 보아, 미래에 과거 자기 작품과 가격경쟁을 해야하는 케이옥션 청년작가...'}]
